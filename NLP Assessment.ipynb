# %% [markdown]
# # Data Science Assignment

# %% [markdown]
# ### The NLP Dataset

# %%
# Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Load Data From CSV File

# %%
# Importing the dataset
dataset1 = pd.read_csv('Data.csv')
dataset = dataset1[['Tweet', 'ADR_label']]
dataset.head()                    # First five dataset
# Out:
#                                                Tweet  ADR_label
# 0      Intravenous azithromycin-induced ototoxicity.          1
# 1  Immobilization, while Paget's bone disease was...          1
# 2  Unaccountable severe hypercalcemia in a patien...          1
# 3  METHODS: We report two cases of pseudoporphyri...          1
# 4  METHODS: We report two cases of pseudoporphyri...          1

# %%
# Shape of the Dataset
dataset.shape
# Out:
# (23516, 2)

# %% [markdown]
# ### Text Cleaning

# %%
# Cleaning the texts
import re
import nltk
nltk.download('stopwords')    # download the irrelavent words. (e.g - this, that, it etc)
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dipes\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset.dtypes   # Types od Dataset
# Out:
# Tweet        object
# ADR_label     int64
# dtype: object

# %%
dataset.count
# Out:
# <bound method DataFrame.count of                                                    Tweet  ADR_label
# 0          Intravenous azithromycin-induced ototoxicity.          1
# 1      Immobilization, while Paget's bone disease was...          1
# 2      Unaccountable severe hypercalcemia in a patien...          1
# 3      METHODS: We report two cases of pseudoporphyri...          1
# 4      METHODS: We report two cases of pseudoporphyri...          1
# ...                                                  ...        ...
# 23511  At autopsy, the liver was found to be small, s...          0
# 23512  Physical exam revealed a patient with aphasia,...          0
# 23513  At the time when the leukemia appeared seven o...          0
# 23514  The American Society for Regional Anesthesia a...          0
# 23515  Concomitant administration of estradiol result...          0
#
# [23516 rows x 2 columns]>

# %% [markdown]
# ## Classify the Tweet into the 2 segments

# %%
# dataset, whose ADR_label = 1
ADR_label1 = dataset[dataset['ADR_label'] == 1]
ADR_label1[0:10]
# Out:
#                                                Tweet  ADR_label
# 0      Intravenous azithromycin-induced ototoxicity.          1
# 1  Immobilization, while Paget's bone disease was...          1
# 2  Unaccountable severe hypercalcemia in a patien...          1
# 3  METHODS: We report two cases of pseudoporphyri...          1
# 4  METHODS: We report two cases of pseudoporphyri...          1
# 5  Naproxen, the most common offender, has been a...          1
# 6  RESULTS: A 44-year-old man taking naproxen for...          1
# 7  RESULTS: A 44-year-old man taking naproxen for...          1
# 8  RESULTS: A 44-year-old man taking naproxen for...          1
# 9  RESULTS: A 44-year-old man taking naproxen for...          1

# %%
# dataset, whose ADR_label = 0
ADR_label0 = dataset[dataset['ADR_label'] == 0]
ADR_label0[0:10]
# Out:
#                                                   Tweet  ADR_label
# 6822  "Retinoic acid syndrome" was prevented with sh...          0
# 6823  BACKGROUND: External beam radiation therapy of...          0
# 6824  Although the enuresis ceased, she developed th...          0
# 6825  A 42-year-old woman had uneventful bilateral l...          0
# 6826  A 16-year-old girl with erosive, polyarticular...          0
# 6827  Resection and use of a cyclooxygenase-2 inhibi...          0
# 6828  Differences in interpretation by patients and ...          0
# 6829  We present a case report of a cytomegalovirus ...          0
# 6830  Dihydropyrimidine dehydrogenase (DPD) is the r...          0
# 6831  The decedent was also prescribed tramadol, gab...          0

# %% [markdown]
# # Data pre-processing and selection

# %% [markdown]
# ### A Sample DataSet

# %%
# Select line 7 for the sample test
review = re.sub('[^a-zA-Z]', ' ', dataset['Tweet'][7])            # WE dan't want to remove the words.
review = review.lower()                                           # Using this code all the upper letter will be change to lower.
review = review.split()                                           # This will split the dataset.
ps = PorterStemmer()                                              # The get root value of the words (eg. Loved = love ).
review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))] # Wil take all the values except stopwords.
review = ' '.join(review)
review
# Out:
# 'result year old man take naproxen chronic low back pain year old woman oxaprozin rheumatoid arthriti present tens bulla cutan fragil face back hand'

# %% [markdown]
# # Append All the Lines

# %% [markdown]
# ## Creating the Bag of Words

# %%
corpus = []
for i in range(0, 23516):
    review = re.sub('[^a-zA-Z]', ' ', dataset['Tweet'][i])            # WE dan't want to remove the words like letter words.
    review = review.lower()                                           # Using this code all the upper letter will be change to lower.
    review = review.split()                                           # This will split the dataset.
    ps = PorterStemmer()                                              # The get root value of the words (eg. Loved = love ).
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))] # Wil take all the values except stopwords.
    review = ' '.join(review)                                         # It join all the bag of words model in a single line. 
    corpus.append(review)

# %%
corpus
# Out:
# ['intraven azithromycin induc ototox',
#  'immobil paget bone diseas present perhap enhanc activ dihydrotachysterol rifampicin could led increas calcium releas circul',
#  'unaccount sever hypercalcemia patient treat hypoparathyroid dihydrotachysterol',
#  'method report two case pseudoporphyria caus naproxen oxaprozin',
#  'method report two case pseudoporphyria caus naproxen oxaprozin',
#  'naproxen common offend associ dimorph clinic pattern pct like present one simul erythropoiet protoporphyria pediatr popul',
#  'result year old man take naproxen chronic low back pain year old woman oxaprozin rheumatoid arthriti present tens bulla cutan fragil face back hand',
#  'result year old man take naproxen chronic low back pain year old woman oxaprozin rheumatoid arthriti present tens bulla cutan fragil face back hand',
#  'result year old man take naproxen chronic low back pain year old woman oxaprozin rheumatoid arthriti present tens bulla cutan fragil face back hand',
#  'result year old man take naproxen chronic low back pain year old woman oxaprozin rheumatoid arthriti present tens bulla cutan fragil face back hand',
#  'background best treat psychot patient past clozapin induc agranulocytosi granulocytopenia remain problem',
#  'conclus result suggest olanzapin may use treat patient clozapin induc granulocytopenia without risk recurr hematolog side effect',
#  'prolong sever fluorouracil associ neurotox patient dihydropyrimidin dehydrogenas defici',
#  'describ side effect fu colon cancer patient suffer sever mucos desquam dermat prolong myelosuppress neurolog toxic requir admiss intens care unit',
#  'describ side effect fu colon cancer patient suffer sever mucos desquam dermat prolong myelosuppress neurolog toxic requir admiss intens care unit',
#  'describ side effect fu colon cancer patient suffer sever mucos desquam dermat prolong myelosuppress neurolog toxic requir admiss intens care unit',
#  'case suggest bh ac deriv cytosin arabinosid beta arabinofuranosylcytosin could caus revers encephalopathi syndrom',
#  'report case revers encephalopathi syndrom year old girl acut myelogen leukemia aml undergo consolid chemotherapi compos bh ac n behenoyl beta arabinofuranosyl cytosin idarubicin',
#  'report case revers encephalopathi syndrom year old girl acut myelogen leukemia aml undergo consolid chemotherapi compos bh ac n behenoyl beta arabinofuranosyl cytosin idarubicin',
#  'one case readministr riluzol follow relaps hepat',
#  'report case two patient develop acut hepat take riluzol recommend dose mg daili week respect',
#  'lupu like syndrom caus aminosalicyl acid patient inflammatori bowel diseas',
#  'although two local anesthet usual caus methemoglobinemia suspect displac lidocain protein bind bupivacain combin metabol acidosi treatment oxid reason develop methemoglobinemia',
#  'methemoglobinemia axillari block bupivacain addit inject lidocain oper field',
#  'methemoglobinemia axillari block bupivacain addit inject lidocain oper field',
#  'report patient chronic renal failur ischem heart diseas develop clinic signific methemoglobinemia axillari block bupivacain addit inject lidocain oper field',
#  'report patient chronic renal failur ischem heart diseas develop clinic signific methemoglobinemia axillari block bupivacain addit inject lidocain oper field',
#  'detect activ eosinophil nasal polyp aspirin induc asthma patient',
#  'episod subacut encephalopathi infus moder dose methotrex mg mtx report young adult metastast gastric cancer',
#  'believ repres unusu case moder dose mtx induc neurotox patient gastric cancer previous report',
#  'describ life threaten side effect acut epoprostenol infus pulmonari edema patient pulmonari hypertens associ limit scleroderma discuss manag potenti etiolog',
#  'year old girl newli diagnos sle develop prurit bullou erupt prednison',
#  'hydroxyurea induc acut interstiti pneumon patient essenti thrombocythemia',
#  'clinic cours suggest interstiti pneumon induc hydroxyurea',
#  'first case hydroxyurea induc acut interstiti pneumon report literatur',
#  'allerg irrit contact dermat calcipotriol',
#  'calcipotriol daivonex r leo pharmaceut zurich switzerland may caus irrit skin wherea allerg reaction less common',
#  'calcipotriol daivonex r leo pharmaceut zurich switzerland may caus irrit skin wherea allerg reaction less common',
#  'present observ suggest batch differ test dose includ lower test dose may help differenti allerg type contact dermat irrit type reaction treatment calcipotriol',
#  'myotonia associ sarcoidosi mark exacerb pravastatin',
#  'pravastatin associ myotonia anim',
#  'case suggest sarcoidosi pravastatin two entiti frequent associ myotonia may interact synergist manner produc sever clinic myotonia human',
#  'hypersensit aspirin manifest acut asthma urticaria angioedema system anaphylactoid reaction',
#  'hypersensit aspirin manifest acut asthma urticaria angioedema system anaphylactoid reaction',
#  'hypersensit aspirin manifest acut asthma urticaria angioedema system anaphylactoid reaction',
#  'conclus fix drug erupt associ mani drug first report omeprazol',
#  'fix drug erupt hand caus omeprazol',
#  'object report describ case fix drug erupt occur omeprazol treatment',
#  'year old japanes man receiv medic attent ulcer coliti one year present diffus erythema pustul face trunk malais fever degre c one day administr salazosulfapyridin',
#  'year old japanes man receiv medic attent ulcer coliti one year present diffus erythema pustul face trunk malais fever degre c one day administr salazosulfapyridin',
#  'year old japanes man receiv medic attent ulcer coliti one year present diffus erythema pustul face trunk malais fever degre c one day administr salazosulfapyridin',
#  'year old japanes man receiv medic attent ulcer coliti one year present diffus erythema pustul face trunk malais fever degre c one day administr salazosulfapyridin',
#  'acut gener exanthemat pustulosi induc salazosulfapyridin patient ulcer coliti',
#  'report case acut gener exanthemat pustulosi agep induc salazosulfapyridin patient ulcer coliti',
#  'case summari year old white jewish schizophren man treat olanzapin develop elev serum ck concentr peak concentr iu l normal',
#  'discuss olanzapin like atyp antipsychot drug may caus muscl injuri concomit elev serum ck muscl origin',
#  'mark elev serum creatin kinas associ olanzapin therapi',
#  'object report case mark elev serum creatin kinas ck associ olanzapin therapi',
#  'diclofenac associ hepat',
#  'patient histori osteoarthr sever hepat week start diclofenac increas pain joint',
#  'cda induc lymphocytopenia may explain improv patient psoriasi',
#  'one case priapism occur heparin therapi previou surgic oper knee report',
#  'priapism complic heparin therapi',
#  'associ heparin priapism often recogn abnorm platelet aggreg could play role pathogenesi side effect',
#  'associ heparin priapism often recogn abnorm platelet aggreg could play role pathogenesi side effect',
#  'carri well known risk neutropenia agranulocytosi necessit immedi discontinu clozapin',
#  'carri well known risk neutropenia agranulocytosi necessit immedi discontinu clozapin',
#  'object report patient develop neutropenia clozapin behind cell count decreas show diurnal variat white blood cell wbc',
#  'acut neutrophil dermatosi induc tran retino acid treatment acut promyelocyt leukemia',
#  'find discontinu rechalleng support assumpt hair loss side effect paroxetin',
#  'hair loss associ paroxetin treatment case report',
#  'report year old femal complain moder hair loss paroxetin treatment',
#  'conclus patient insulin allergi may complet resolut symptom standard desensit particularli patient concomit protamin allergi',
#  'method patient requir insulin desensit sever urticaria angioedema occasion wheez result insulin dose',
#  'method patient requir insulin desensit sever urticaria angioedema occasion wheez result insulin dose',
#  'method patient requir insulin desensit sever urticaria angioedema occasion wheez result insulin dose',
#  'method patient requir insulin desensit sever urticaria angioedema occasion wheez result insulin dose',
#  'method patient requir insulin desensit sever urticaria angioedema occasion wheez result insulin dose',
#  'method patient requir insulin desensit sever urticaria angioedema occasion wheez result insulin dose',
#  'object purpos studi determin whether desensit nph insulin well standard insulin desensit could control allerg symptom patient allerg nph regular insulin',
#  'object purpos studi determin whether desensit nph insulin well standard insulin desensit could control allerg symptom patient allerg nph regular insulin',
#  'patient receiv neutral protamin hagedorn nph insulin increas risk develop protamin hypersensit',
#  'protamin allergi complic insulin hypersensit case report',
#  'continu receiv regular insulin time per day follow year occasion hive',
#  'patient recurr urticaria angioedema year half later point nph stop desensit regular insulin',
#  'patient recurr urticaria angioedema year half later point nph stop desensit regular insulin',
#  'patient recurr urticaria angioedema year half later point nph stop desensit regular insulin',
#  'patient recurr urticaria angioedema year half later point nph stop desensit regular insulin',
#  'month old infant becam letharg poorli respons receiv drop brimonidin eye',
#  'month old infant becam letharg poorli respons receiv drop brimonidin eye',
#  'day old infant becam letharg apneic singl drop brimonidin',
#  'day old infant becam letharg apneic singl drop brimonidin',
#  'appar central nervou system depress infant use topic brimonidin',
#  'conclus topic brimonidin may associ central nervou system depress infant',
#  'purpos report two case topic brimonidin result appar central nervou system depress unrespons infant',
#  'ceftriaxon approv treatment otiti media despit previou studi document associ ceftriaxon elev hepato biliari enzym transient biliari stasi',
#  'ceftriaxon approv treatment otiti media despit previou studi document associ ceftriaxon elev hepato biliari enzym transient biliari stasi',
#  'hepato biliari abnorm secondari ceftriaxon use case report',
#  'anterior lumbosacr radiculopathi intrathec methotrex treatment',
#  'report three children develop progress paraparesi intrathec methotrex administr follow complet partial recoveri',
#  'first day arsen trioxid treatment rapid decreas dimer seen normal valu reach day togeth slight decreas peripher blood leukocyt',
#  'first day arsen trioxid treatment rapid decreas dimer seen normal valu reach day togeth slight decreas peripher blood leukocyt',
#  'year old black man develop fever chill fatigu night sweat tender lymphadenopathi gener prurit macular erupt week start minocyclin therapi acn',
#  'year old black man develop fever chill fatigu night sweat tender lymphadenopathi gener prurit macular erupt week start minocyclin therapi acn',
#  'year old black man develop fever chill fatigu night sweat tender lymphadenopathi gener prurit macular erupt week start minocyclin therapi acn',
#  'year old black man develop fever chill fatigu night sweat tender lymphadenopathi gener prurit macular erupt week start minocyclin therapi acn',
#  'year old black man develop fever chill fatigu night sweat tender lymphadenopathi gener prurit macular erupt week start minocyclin therapi acn',
#  'neg viral serolog clinic pictur consist infecti mononucleosi like syndrom produc minocyclin ingest',
#  'conclud presenc metabol defect combin topic fu drug demonstr narrow therapeut index result unusu present life threaten toxic treatment topic drug',
#  'report first known cancer patient develop life threaten complic treatment topic fu shown subsequ profound dpd defici',
#  'acut ischaem event associ use venlafaxin case report propos pathophysiolog mechan',
#  'associ venlafaxin treatment ischaem event could explain uniqu pharmacolog haemodynam properti',
#  'first report possibl associ acut cardiovascular event venlafaxin',
#  'present case elderli woman pre exist histori ischaem heart diseas treat venlafaxin develop acut myocardi ischaemia within first week treatment',
#  'appar cyclophosphamid cytoxan embryopathi distinct phenotyp',
#  'purpos report document new case utero cp exposur multipl congenit anomali establish appar cp embryopathi phenotyp',
#  'purpos report document new case utero cp exposur multipl congenit anomali establish appar cp embryopathi phenotyp',
#  'report case utero exposur cyclosposphamid share follow manifest patient growth defici development delay craniosynostosi blepharophimosi flat nasal bridg abnorm ear distal limb defect includ hypoplast thumb oligodactyli',
#  'report case utero exposur cyclosposphamid share follow manifest patient growth defici development delay craniosynostosi blepharophimosi flat nasal bridg abnorm ear distal limb defect includ hypoplast thumb oligodactyli',
#  'report case utero exposur cyclosposphamid share follow manifest patient growth defici development delay craniosynostosi blepharophimosi flat nasal bridg abnorm ear distal limb defect includ hypoplast thumb oligodactyli',
#  'report case utero exposur cyclosposphamid share follow manifest patient growth defici development delay craniosynostosi blepharophimosi flat nasal bridg abnorm ear distal limb defect includ hypoplast thumb oligodactyli',
#  'report case utero exposur cyclosposphamid share follow manifest patient growth defici development delay craniosynostosi blepharophimosi flat nasal bridg abnorm ear distal limb defect includ hypoplast thumb oligodactyli',
#  'report case utero exposur cyclosposphamid share follow manifest patient growth defici development delay craniosynostosi blepharophimosi flat nasal bridg abnorm ear distal limb defect includ hypoplast thumb oligodactyli',
#  'report case utero exposur cyclosposphamid share follow manifest patient growth defici development delay craniosynostosi blepharophimosi flat nasal bridg abnorm ear distal limb defect includ hypoplast thumb oligodactyli',
#  'conclud cyclophosphamid human teratogen b distinct phenotyp exist c safeti cp pregnanc seriou question',
#  'case seizur control withdraw phenytoin reduct drug level',
#  'paradox seizur phenytoin toxic',
#  'present three patient paradox seizur serum phenytoin level mcg ml mcg ml mcg ml',
#  'conclus case suggest losartan induc late onset angioedema patient normal renal function reaction recur initi resolut symptom',
#  'losartan induc angioedema',
#  'object report case angioedema associ losartan administr',
#  'incid angioedema secondari losartan angiotensin ii receptor antagonist unknown',
#  'report case femal acromegal patient multipl hepat adenoma appear soon danazol treatment uterin fibromatosi',
#  'heparin induc thrombocytopenia rare seriou complic anticoagul therapi',
#  'pediatr heparin induc thrombocytopenia manag danaparoid orgaran',
#  'remain pauciti inform pertain altern anticoagul strategi use cardiopulmonari bypass concomit heparin induc thrombocytopenia especi children',
#  'report success treatment heparin induc thrombocytopenia subsequ hemorrhag complic postop year old child danaparoid orgaran',
#  'report success treatment heparin induc thrombocytopenia subsequ hemorrhag complic postop year old child danaparoid orgaran',
#  'taxan induc glaucoma',
#  'report case glaucoma induc doxetaxel therapi metastat breast cancer',
#  'acut hyperphosphatemia caus sodium phosphat enema patient liver dysfunct chronic renal failur',
#  'report case acut hyperphosphatemia secondari rectal administr sodium phosphat sodium biphosph fleet enema',
#  'report case acut hyperphosphatemia secondari rectal administr sodium phosphat sodium biphosph fleet enema',
#  'prolong qt interv ventricular tachyarrhymia describ patient amiodaron therapi',
#  'prolong qt interv ventricular tachyarrhymia describ patient amiodaron therapi',
#  'report case recurr torsad de point follow treatment pentaval antimoni drug amiodaron',
#  'emphasi given differenti diphenylhydantoin induc gingiv hyperplasia angiomat enlarg gingiva treatment plan',
#  'year old japanes woman sever scleroderma develop anemia thrombocytopenia due penicillamin pen treatment although leukopenia markedli sever',
#  'year old japanes woman sever scleroderma develop anemia thrombocytopenia due penicillamin pen treatment although leukopenia markedli sever',
#  'year old japanes woman sever scleroderma develop anemia thrombocytopenia due penicillamin pen treatment although leukopenia markedli sever',
#  'year old japanes woman sever scleroderma develop anemia thrombocytopenia due penicillamin pen treatment although leukopenia markedli sever',
#  'cessat pen start corticosteroid therapi follow recoveri bicytopenia',
#  'vitro inhibit hematopoiesi patient system sclerosi treat penicillamin',
#  'find suggest bicytopenia patient caus pen may due differ sensit hematopoiet lineag',
#  'year old woman treat thyrotoxicosi methimazol develop agranulocytosi',
#  'postop hypocalcem tetani caus fleet phospho soda prepar patient take alendron sodium report case',
#  'postop hypocalcem tetani caus fleet phospho soda prepar patient take alendron sodium report case',
#  'case report describ patient previous prescrib alendron fosamax present postop hypophosphatemia hypocalcem tetani bowel prepar fleet phospho soda',
#  'case report describ patient previous prescrib alendron fosamax present postop hypophosphatemia hypocalcem tetani bowel prepar fleet phospho soda',
#  'case report describ patient previous prescrib alendron fosamax present postop hypophosphatemia hypocalcem tetani bowel prepar fleet phospho soda',
#  'case report describ patient previous prescrib alendron fosamax present postop hypophosphatemia hypocalcem tetani bowel prepar fleet phospho soda',
#  'case report describ patient previous prescrib alendron fosamax present postop hypophosphatemia hypocalcem tetani bowel prepar fleet phospho soda',
#  'case report describ patient previous prescrib alendron fosamax present postop hypophosphatemia hypocalcem tetani bowel prepar fleet phospho soda',
#  'describ patient develop thrombot microangiopathi kidney receiv high cumul dose new anticanc drug gemcitabin',
#  'thrombot microangiopathi renal failur two patient undergo gemcitabin chemotherapi',
#  'thrombot microangiopathi renal failur two patient undergo gemcitabin chemotherapi',
#  'first patient year old man year histori fistul cd b cell non hodgkin lymphoma diagnos month treatment infliximab',
#  'relationship infliximab treatment lymphoma crohn diseas',
#  'second year old man cd nodular scleros hodgkin lymphoma diagnos week infus infliximab',
#  'describ clinic cours patient crohn diseas cd lymphoma diagnos treatment infliximab',
#  'codein intox neonat',
#  'report case codein intox neonat drug prescrib cough control emerg depart visit',
#  'hydroxyurea hu sodium phenylbutyr spb shown increas fetal hemoglobin hb f level patient thalassemia intermedia',
#  'hydroxyurea hu sodium phenylbutyr spb shown increas fetal hemoglobin hb f level patient thalassemia intermedia',
#  'four patient respond hu increas total hb report symptomat improv three requir transfus',
#  'prolong respons achiev low dose hu mg kg day higher dose associ mild revers hematolog hepat toxic increas hb',
#  'prolong respons achiev low dose hu mg kg day higher dose associ mild revers hematolog hepat toxic increas hb',
#  'sodium phenylbutyr ad treatment hu two patient fail produc increas total hb despit increas hb f level',
#  'sodium phenylbutyr ad treatment hu two patient fail produc increas total hb despit increas hb f level',
#  'conclud low dose hu therapi patient thalassemia intermedia may increas total hb level suffici elimin need transfus',
#  'describ clinic respons determin increas total hb decreas transfus need five patient thalassemia intermedia treat hu alon combin spb',
#  'describ clinic respons determin increas total hb decreas transfus need five patient thalassemia intermedia treat hu alon combin spb',
#  'patient schizophrenia consum gradual increas quantiti oolong tea eventu reach l day becam deliri admit psychiatr hospit',
#  'abstin oolong tea delirium resolv',
#  'sever rhabdomyolysi follow massiv ingest oolong tea caffein intox coexist hyponatremia',
#  'sever rhabdomyolysi follow massiv ingest oolong tea caffein intox coexist hyponatremia',
#  'sever rhabdomyolysi follow massiv ingest oolong tea caffein intox coexist hyponatremia',
#  'sever rhabdomyolysi follow massiv ingest oolong tea caffein intox coexist hyponatremia',
#  'clinic cours suggest caffein present oolong tea mainli respons rhabdomyolysi well delirium although sever hyponatremia report caus rhabdomyolysi rare occas',
#  'clinic cours suggest caffein present oolong tea mainli respons rhabdomyolysi well delirium although sever hyponatremia report caus rhabdomyolysi rare occas',
#  'clinic cours suggest caffein present oolong tea mainli respons rhabdomyolysi well delirium although sever hyponatremia report caus rhabdomyolysi rare occas',
#  'clinic cours suggest caffein present oolong tea mainli respons rhabdomyolysi well delirium although sever hyponatremia report caus rhabdomyolysi rare occas',
#  'possibl sever rhabdomyolysi consid patient water intox due massiv ingest caffein contain beverag',
#  'possibl sever rhabdomyolysi consid patient water intox due massiv ingest caffein contain beverag',
#  'hypothes caffein toxic injur muscl cell fragil due potassium deplet induc coexist hyponatremia result unusu sever rhabdomyolysi',
#  'hypothes caffein toxic injur muscl cell fragil due potassium deplet induc coexist hyponatremia result unusu sever rhabdomyolysi',
#  'hypothes caffein toxic injur muscl cell fragil due potassium deplet induc coexist hyponatremia result unusu sever rhabdomyolysi',
#  'hypothes caffein toxic injur muscl cell fragil due potassium deplet induc coexist hyponatremia result unusu sever rhabdomyolysi',
#  'hypothes caffein toxic injur muscl cell fragil due potassium deplet induc coexist hyponatremia result unusu sever rhabdomyolysi',
#  'addit citalopram desmethylclomipramin plasma level increas hydroaci desmethylclomipramin plasma level decreas observ',
#  'addit citalopram desmethylclomipramin plasma level increas hydroaci desmethylclomipramin plasma level decreas observ',
#  'report case hiv infect patient experienc symptomat angiolipoma shortli start antiretrovir therapi includ proteas inhibitor indinavir',
#  'elev serum triglycerid clozapin resolv risperidon four patient',
#  'two patient clozapin reinstat risperidon discontinu serum triglycerid level increas',
#  'increas clozapin switch risperidon vice versa consist previou report elev serum triglycerid level clozapin treat patient',
#  'intraven valproat associ signific hypotens treatment statu epilepticu',
#  'knowledg first report signific hypotens associ intraven valproat treatment statu epilepticu pediatr popul',
#  'report case sever hypotens associ intraven valproat use treat statu epilepticu year old girl',
#  'patient rippl phenomena worsen pyridostigmin treatment markedli improv immunosuppress azathioprin',
#  'diagnosi mask theophyllin poison consid similar situat involv rapid decreas insulin requir',
#  'salicyl intox exclud theophyllin final incrimin',
#  'theophyllin intox mimick diabet ketoacidosi child',
#  'compound use adult child home caus accident theophyllin poison mimick diabet ketoacidosi',
#  'methylen blue treatment prevent ifosfamid induc encephalopathi report case review literatur',
#  'ten patient treat ifosfamid develop encephalopathi',
#  'conclud mb effect treatment ifosfamid induc encephalopathi',
#  'portal vein thrombosi patient sever haemophilia f v g mutat continu infus f viii intramur jejun bleed success thrombolysi heparin therapi',
#  'report year old boy sever haemophilia develop portal vein thrombosi continu infus f viii',
#  'year old woman diabet mellitu type develop acut icter hepat like ill week initi gliclazid therapi',
#  'gliclazid induc acut hepat',
#  'conclus case strongli suggest gliclazid induc acut icter liver necro inflamm may misdiagnos clinic acut viral hepat',
#  'believ first descript acut hepat caus idiosyncrat advers reaction gliclazid one metabolit',
#  'describ case acut hepat induc gliclazid second gener sulfonylurea',
#  'caution therefor need prevent undesir accumul tca may lead protract cush syndrom',
#  'cush syndrom persist month tca concentr remain detect least day',
#  'present patient treat mg tca develop cush syndrom week later cortisol acth concentr limit detect tca concentr microgram l',
#  'impair lung function abnorm comput tomograph scan condit improv nitrofurantoin withdrawn corticosteroid treatment commenc',
#  'impair lung function abnorm comput tomograph scan condit improv nitrofurantoin withdrawn corticosteroid treatment commenc',
#  'bronchiol obliteran organis pneumonia associ use nitrofurantoin',
#  'case histori present two patient develop lung diseas associ use nitrofurantoin histolog featur bronchiol obliteran organis pneumonia boop rare recognis form drug induc injuri',
#  'case histori present two patient develop lung diseas associ use nitrofurantoin histolog featur bronchiol obliteran organis pneumonia boop rare recognis form drug induc injuri',
#  'case histori present two patient develop lung diseas associ use nitrofurantoin histolog featur bronchiol obliteran organis pneumonia boop rare recognis form drug induc injuri',
#  'favour outcom two patient contrast fatal outcom two report case nitrofurantoin induc boop',
#  'favour outcom two patient contrast fatal outcom two report case nitrofurantoin induc boop',
#  'spectrum nitrofurantoin lung injuri continu widen',
#  'two middl age women present respiratori symptom prolong treatment nitrofurantoin',
#  'suggest previou classif nitrofurantoin induc lung injuri acut chronic injuri oversimplif view wide varieti patholog entiti subsequ emerg',
#  'intraven administr levodopa amelior refractori akathisia case induc interferon alpha',
#  'present report illustr rare case refractori akathisia interferon alpha treatment also levodopa treatment would theoret practic use reduc neurotox associ interferon alpha',
#  'present report illustr rare case refractori akathisia interferon alpha treatment also levodopa treatment would theoret practic use reduc neurotox associ interferon alpha',
#  'acut erythroid leukemia cyclophosphamid therapi multipl myeloma report two case',
#  'develop erythroid leukemia plu carcinoma two men suggest mutagen chang secondari cyclophosphamid therapi',
#  'scleroderma like reaction induc uracil tegafur uft second gener anticanc agent',
#  'scleroderma like reaction induc uracil tegafur uft second gener anticanc agent',
#  'first report uft induc scleroderma like reaction',
#  'report case scleroderma like reaction induc long term administr uft',
#  'central nervou system manifest ibuprofen overdos revers naloxon',
#  'ibuprofen overdos usual character gi upset dizzi mild sedat',
#  'ibuprofen overdos usual character gi upset dizzi mild sedat',
#  'ibuprofen overdos usual character gi upset dizzi mild sedat',
#  'present treatment acut ibuprofen intox complic requir support therapi symptom resolv hour',
#  'report case month old femal infant depress level conscious ingest ibuprofen whose mental statu markedli improv administr naloxon',
#  'flecainid associ pneumon acut respiratori failur patient leopard syndrom',
#  'flecainid associ pneumon acut respiratori failur patient leopard syndrom',
#  'flecainid rare caus hypersensit pneumon case report',
#  'describ case interstiti hypoxaemi pneumon probabl relat flecainid patient leopard syndrom rare congenit disord',
#  'sagitt sinu thrombosi associ transient free protein defici l asparaginas treatment case report review literatur',
#  'sagitt sinu thrombosi associ transient free protein defici l asparaginas treatment case report review literatur',
#  'report case adult patient acut lymphoblast leukemia present repeat transient ischem attack follow seizur consolid treatment l asparaginas',
#  'report case adult patient acut lymphoblast leukemia present repeat transient ischem attack follow seizur consolid treatment l asparaginas',
#  'report young adolesc benign intracrani hypertens attribut use minocyclin acn',
#  'report patient develop polyarter nodosa follow vaccin hepat b',
#  'case suspect combin cigarett smoke pulmonari fibrosi low dose methotrex therapi might promot develop lung cancer',
#  'case report illustr use continu high dose intracoronari nitroglycerin infus french coronari guid cathet treatment patient cocain induc refractori coronari vasospasm',
#  'howev illustr case report date onset troglitazon induc liver injuri insidi tempor variabl',
#  'remain seen whether hepatotox associ troglitazon drug class effect specif troglitazon',
#  'remain seen whether hepatotox associ troglitazon drug class effect specif troglitazon',
#  'thiazolidinedion current clinic trial may abl provid therapeut benefit troglitazon without signific hepatotox',
#  'three report case demonstr troglitazon idiosyncrat hepatotoxin lead irrevers liver injuri',
#  'troglitazon induc fulmin hepat failur',
#  'nitrofurantoin induc lung diseas two case demonstr resolut appar irrevers ct abnorm',
#  'present two case nitrofurantoin induc pulmonari toxic initi hrct show widespread reticular pattern associ distort lung parenchyma thought repres establish fibrosi',
#  'present two case nitrofurantoin induc pulmonari toxic initi hrct show widespread reticular pattern associ distort lung parenchyma thought repres establish fibrosi',
#  'present two case nitrofurantoin induc pulmonari toxic initi hrct show widespread reticular pattern associ distort lung parenchyma thought repres establish fibrosi',
#  'present two case nitrofurantoin induc pulmonari toxic initi hrct show widespread reticular pattern associ distort lung parenchyma thought repres establish fibrosi',
#  'fluoxetin relat death child cytochrom p genet defici',
#  'medic examin report indic death caus fluoxetin toxic',
#  'medic examin report indic death caus fluoxetin toxic',
#  'first report fluoxetin relat death child confirm genet polymorph cyp gene result impair drug metabol',
#  'year old woman histori migrain without aura predominantli occur around menstrual period develop spinal cord lesion follow use zolmitriptan',
#  'spinal cord infarct use zolmitriptan case report',
#  'tempor relationship suggest spinal cord infarct may relat use zolmitriptan',
#  'case summari year old white girl bilater optic glioma develop hypersensit reaction carboplatin nine cours',
#  'regimen could prove use patient develop hypersensit reaction carboplatin allow therapi continu',
#  'perinat vasoconstrict renal insuffici associ matern nimesulid use',
#  'first report advers effect fetal renal circul matern ingest nimesulid',
#  'although aml develop follow oral etoposid therapi child previous receiv high dose multiag chemotherapi rearrang mll gene demonstr',
#  'secondari leukemia child neuroblastoma oral etoposid caus',
#  'author present case aml develop child metastat neuroblastoma month receiv oral etoposid given palliat purpos',
#  'background cyanamid avers agent wide use japan known induc variou degre hepat lesion ground glass inclus bodi',
#  'case year old male alcohol remain complet abstin cyanamid treatment year complain gener fatigu',
#  'case year old femal alcohol complain gener fatigu slight fever year abstin cyanamid treatment',
#  'case year old femal alcohol complain gener fatigu slight fever year abstin cyanamid treatment',
#  'case year old male alcohol remain complet abstin take cyanamid year show slight elev serum transaminas',
#  'conclus abstain take cyanamid sever year thin septum like liver fibrosi progress along emerg ground glass hepatocyt',
#  'conclus abstain take cyanamid sever year thin septum like liver fibrosi progress along emerg ground glass hepatocyt',
#  'cyanamid induc liver dysfunct abstin alcohol long term follow studi four case',
#  'cyanamid treat alcohol relaps drink sever inflamm develop liver',
#  'patient allergi macrolid antibiot given tacrolimu develop sudden cutan reaction',
#  'year old woman histori epilepsi present probabl nonconvuls statu epilepticu receiv continu intraven morphin back pain relat vertebr metastasi malign lymphoma',
#  'gener tonic clonic seizur occur minut inject morphin antagonist naloxon',
#  'nonconvuls statu epilepticu role morphin antagonist',
#  'spontan bacteri periton induc intraarteri vasopressin therapi',
#  'although literatur use risperidon elderli patient dementia consist larg uncontrol trial case report chart review appear agent effect manag agit popul low frequenc extrapyramid symptom ep',
#  'although literatur use risperidon elderli patient dementia consist larg uncontrol trial case report chart review appear agent effect manag agit popul low frequenc extrapyramid symptom ep',
#  'three month follow splenectomi multipl abscess occur muscl thigh patient receiv third cours chop regimen',
#  'seven month continu treatment suspect tuberculosi rifampicin ethambutol nine year old boy develop polyarthr rash hepat associ anti nativ dna antibodi posit antinuclear factor',
#  'seven month continu treatment suspect tuberculosi rifampicin ethambutol nine year old boy develop polyarthr rash hepat associ anti nativ dna antibodi posit antinuclear factor',
#  'seven month continu treatment suspect tuberculosi rifampicin ethambutol nine year old boy develop polyarthr rash hepat associ anti nativ dna antibodi posit antinuclear factor',
#  'seven month continu treatment suspect tuberculosi rifampicin ethambutol nine year old boy develop polyarthr rash hepat associ anti nativ dna antibodi posit antinuclear factor',
#  'polyarthr hepat anti nativ dna antibodi treatment ethambutol rifampicin',
#  'polyarthr hepat anti nativ dna antibodi treatment ethambutol rifampicin',
#  'polyarthr hepat anti nativ dna antibodi treatment ethambutol rifampicin',
#  'polyarthr hepat anti nativ dna antibodi treatment ethambutol rifampicin',
#  'polyarthr hepat anti nativ dna antibodi treatment ethambutol rifampicin',
#  'polyarthr hepat anti nativ dna antibodi treatment ethambutol rifampicin',
#  'case normotens scleroderma renal crisi high dose methylprednisolon treatment',
#  'hu report sever anticanc chemotherapi often mitomycin c base chemotherapi regimen',
#  'sever hemolyt urem syndrom advanc ovarian cancer patient treat carboplatin gemcitabin',
#  'sever hemolyt urem syndrom advanc ovarian cancer patient treat carboplatin gemcitabin',
#  'present case hu advanc ovarian cancer patient treat carboplatin gemcitabin describ favor outcom chemotherapi interrupt support care year follow',
#  'present case hu advanc ovarian cancer patient treat carboplatin gemcitabin describ favor outcom chemotherapi interrupt support care year follow',
#  'evalu ovarian structur function consid women reproduct age treat valproat epilepsi especi develop menstrual cycl disturb treatment',
#  'background reproduct endocrin disord character menstrual disord polycyst ovari hyperandrogen seem common among women treat sodium valproat epilepsi',
#  'background reproduct endocrin disord character menstrual disord polycyst ovari hyperandrogen seem common among women treat sodium valproat epilepsi',
#  'background reproduct endocrin disord character menstrual disord polycyst ovari hyperandrogen seem common among women treat sodium valproat epilepsi',
#  'background reproduct endocrin disord character menstrual disord polycyst ovari hyperandrogen seem common among women treat sodium valproat epilepsi',
#  'conclus case present illustr develop reproduct endocrin disord initi valproat therapi women epilepsi',
#  'object describ develop valproat relat reproduct endocrin disord women epilepsi',
#  'patient three patient develop reproduct endocrin disord treatment valproat',
#  'result replac valproat lamotrigin result decreas serum testosteron concentr women',
#  'polycyst chang disappear ovari women valproat therapi discontinu women gain weight develop amenorrhea treat valproat lost weight resum menstruat chang medic',
#  'polycyst chang disappear ovari women valproat therapi discontinu women gain weight develop amenorrhea treat valproat lost weight resum menstruat chang medic',
#  'polycyst chang disappear ovari women valproat therapi discontinu women gain weight develop amenorrhea treat valproat lost weight resum menstruat chang medic',
#  'howev recurr staphylococcu aureu sepsi develop cya therapi',
#  'recurr septicemia lethal outcom cyclosporin therapi sever ulcer coliti',
#  'recurr septicemia lethal outcom cyclosporin therapi sever ulcer coliti',
#  'year old woman chronic renal failur develop acut proxim muscl weak receiv regular dosag colchicin',
#  'colchicin induc myopathi renal failur',
#  'muscl biopsi reveal variat muscl fiber size vacuol fiber featur colchicin induc myopathi',
#  'muscl biopsi reveal variat muscl fiber size vacuol fiber featur colchicin induc myopathi',
#  'muscl biopsi reveal variat muscl fiber size vacuol fiber featur colchicin induc myopathi',
#  'third patient experienc disabl neurotox extrem prior ulnar nerv tendon transposit receiv paclitaxel',
#  'phantom limb pain manifest paclitaxel neurotox',
#  'phantom limb pain manifest paclitaxel neurotox',
#  'physician awar plp occur initi paclitaxel',
#  'describ patient prior amput experienc phantom limb pain plp receiv paclitaxel therapi',
#  'describ patient prior amput experienc phantom limb pain plp receiv paclitaxel therapi',
#  'skin manifest case phenylbutazon induc serum sick like reaction',
#  'skin manifest case phenylbutazon induc serum sick like reaction',
#  'experi support hemodialysi esrf patient atenolol toxic',
#  'allerg reaction gemfibrozil manifest eosinophil gastroenter',
#  'describ case ege manifest allergi gemfibrozil',
#  'second report lactic acidosi patient stavudin lamivudin',
#  'second report lactic acidosi patient stavudin lamivudin',
#  'present aid patient sever prolong lactic acidosi stavudin lamivudin',
#  'present aid patient sever prolong lactic acidosi stavudin lamivudin',
#  'ataxia caus propafenon report pharmaceut compani drug monitor agenc well describ emphas medic literatur',
#  'wide varieti advers central nervou system effect report associ propafenon dizzi common',
#  'wide varieti advers central nervou system effect report associ propafenon dizzi common',
#  'propafenon induc ataxia report three case',
#  'describ elderli patient moder sever ataxia occur take propafenon',
#  'year old man receiv oral administr pilsicainid pure sodium channel blocker slow recoveri kinet convert paroxysm atrial fibril sinu rhythm develop loss conscious two day later',
#  'pilsicainid prescrib patient coronari arteri diseas renal dysfunct close attent must paid avoid life threaten arrhythmia due high plasma concentr drug',
#  'case import document drug induc dystonia occur patient dementia risperidon appear contribut dystonia among elderli patient categor dyston reaction need clarif',
#  'provoc non convuls statu epilepticu tiagabin three adolesc patient',
#  'event non convuls statu epilepticu subsid follow reduct tiagabin dosag',
#  'first report non convuls statu epilepticu provok tiagabin adolesc patient',
#  'mani report probabl lithium induc organ brain syndrom occur serum lithium level within close therapeut rang',
#  'acut manic state character mark psychot symptom intens anxieti may associ increas vulner develop sever lithium neurotox',
#  'acut manic state character mark psychot symptom intens anxieti may associ increas vulner develop sever lithium neurotox',
#  'acut manic state character mark psychot symptom intens anxieti may associ increas vulner develop sever lithium neurotox',
#  'proteas inhibitor induc carbamazepin toxic',
#  'proteas inhibitor ritonavir saquinavir ad treatment patient develop progress ataxia relat carbamazepin toxic',
#  'proteas inhibitor ritonavir saquinavir ad treatment patient develop progress ataxia relat carbamazepin toxic',
#  'proteas inhibitor ritonavir saquinavir ad treatment patient develop progress ataxia relat carbamazepin toxic',
#  'proteas inhibitor ritonavir saquinavir ad treatment patient develop progress ataxia relat carbamazepin toxic',
#  'proteas inhibitor ritonavir saquinavir ad treatment patient develop progress ataxia relat carbamazepin toxic',
#  'proteas inhibitor ritonavir saquinavir ad treatment patient develop progress ataxia relat carbamazepin toxic',
#  'ritonavir act cyp inhibitor diminish carbamazepin metabol provok increas serum level clinic toxic',
#  'ritonavir act cyp inhibitor diminish carbamazepin metabol provok increas serum level clinic toxic',
#  'ritonavir act cyp inhibitor diminish carbamazepin metabol provok increas serum level clinic toxic',
#  'patient diagnos carbamazepin toxic relat introduct ritonavir',
#  'patient diagnos carbamazepin toxic relat introduct ritonavir',
#  'anaphylaxi calcitonin',
#  'conclus introduc case anaphylaxi calcitonin suggest ige mediat hypersensit reaction',
#  'intramuscular challeng test ui miacalc posit immedi anaphylact reaction',
#  'introduc case sixti year old woman sever previou episod rhiniti conjunct perspir immedi administr salmon calcitonin nasal spray intramuscular administr calsynar',
#  'introduc case sixti year old woman sever previou episod rhiniti conjunct perspir immedi administr salmon calcitonin nasal spray intramuscular administr calsynar',
#  'introduc case sixti year old woman sever previou episod rhiniti conjunct perspir immedi administr salmon calcitonin nasal spray intramuscular administr calsynar',
#  'introduc case sixti year old woman sever previou episod rhiniti conjunct perspir immedi administr salmon calcitonin nasal spray intramuscular administr calsynar',
#  'introduc case sixti year old woman sever previou episod rhiniti conjunct perspir immedi administr salmon calcitonin nasal spray intramuscular administr calsynar',
#  'introduc case sixti year old woman sever previou episod rhiniti conjunct perspir immedi administr salmon calcitonin nasal spray intramuscular administr calsynar',
#  'minocyclin caus drug induc autoimmun hepat',
#  'minocyclin induc autoimmun hepat usual ident sporad autoimmun hepat',
#  'describ clinic liver biopsi morpholog featur patient minocyclin induc autoimmun hepat group',
#  'l asparaginas provok seizur singular express central nervou toxic',
#  'l asparaginas provok seizur singular express central nervou toxic',
#  'patient treat l asparaginas may present hemorrhag thrombot cerebrovascular event',
#  'patient treat l asparaginas may present hemorrhag thrombot cerebrovascular event',
#  'report case seizur associ l asparaginas therapi evid hemorrhag thrombot cerebrovascular event',
#  'eighti two patient variou malign receiv imipenem cilastatin time neutropen fever march octob depart pediatr oncolog gazi univers identifi',
#  'eighti two patient variou malign receiv imipenem cilastatin time neutropen fever march octob depart pediatr oncolog gazi univers identifi',
#  'incid seizur pediatr cancer patient treat imipenem cilastatin',
#  'incid seizur pediatr cancer patient treat imipenem cilastatin',
#  'proconvuls tendenc imipenem cilastatin one well known side effect',
#  'proconvuls tendenc imipenem cilastatin one well known side effect',
#  'three patient convuls attribut imipenem cilastatin patient seizur imipenem cilastatin administr follow seizur attack',
#  'three patient convuls attribut imipenem cilastatin patient seizur imipenem cilastatin administr follow seizur attack',
#  'three patient convuls attribut imipenem cilastatin patient seizur imipenem cilastatin administr follow seizur attack',
#  'three patient convuls attribut imipenem cilastatin patient seizur imipenem cilastatin administr follow seizur attack',
#  'three patient convuls attribut imipenem cilastatin patient seizur imipenem cilastatin administr follow seizur attack',
#  'three patient convuls attribut imipenem cilastatin patient seizur imipenem cilastatin administr follow seizur attack',
#  'gabapentin induc mood chang hypoman featur adult',
#  'gabapentin induc mood chang hypoman featur adult',
#  'report two adult receiv gabapentin gbp subsequ develop behaviour side effect',
#  'report two adult receiv gabapentin gbp subsequ develop behaviour side effect',
#  'acut pancreat child idiopath ulcer coliti long term aminosalicyl acid therapi',
#  'describ year old boy ulcer coliti develop acut pancreat long term treatment aminosalicyl acid',
#  'conclus mark visual field constrict appear associ vigabatrin therapi',
#  'electro oculographi electroretinographi visual evok potenti multifoc electroretinographi patient vigabatrin attribut visual field constrict',
#  'purpos symptomat visual field constrict thought associ vigabatrin report',
#  'current studi investig visual field visual electrophysiolog eight patient known vigabatrin attribut visual field loss three report previous',
#  'field defect electrophysiolog abnorm persist vigabatrin therapi withdrawn',
#  'depress symptom disappear interferon therapi stop',
#  'treatment chronic hepat c interferon alpha ifn alpha rel contraind patient psychiatr disord possibl sever psychiatr side effect',
#  'treatment chronic hepat c interferon alpha ifn alpha rel contraind patient psychiatr disord possibl sever psychiatr side effect',
#  'ribavirin antidepress effect known suppos antidepress may prevent chang serotonerg noradrenerg neurotransmiss caus ifn alpha',
#  'intens high flux hemodiafiltr often use manag vancomycin toxic',
#  'manag hypophosphatemia induc high flux hemodiafiltr treatment vancomycin toxic intraven phosphoru therapi versu use phosphoru enrich dialys',
#  'describ children cerebr palsi suffer signific morbid immedi treatment hyperbar oxygen',
#  'year old male present brown discolour fingernail follow applic hydroquinon sorbolen cream tretinoin cream face intermitt month',
#  'year old male present brown discolour fingernail follow applic hydroquinon sorbolen cream tretinoin cream face intermitt month',
#  'nail stain hydroquinon cream',
#  'gangren fingertip bleomycin methotrex',
#  'gangren fingertip bleomycin methotrex',
#  'support well report potenti bleomycin trigger acral vascular toxic',
#  'describ year old man acral erythrocyanosi progress acut digit ischemia gangren develop combin chemotherapi bleomycin methotrex use treat metastat squamou cell carcinoma hypopharynx',
#  'describ year old man acral erythrocyanosi progress acut digit ischemia gangren develop combin chemotherapi bleomycin methotrex use treat metastat squamou cell carcinoma hypopharynx',
#  'describ year old man acral erythrocyanosi progress acut digit ischemia gangren develop combin chemotherapi bleomycin methotrex use treat metastat squamou cell carcinoma hypopharynx',
#  'describ year old man acral erythrocyanosi progress acut digit ischemia gangren develop combin chemotherapi bleomycin methotrex use treat metastat squamou cell carcinoma hypopharynx',
#  'diarrhea associ anticoagul patient take warfarin therapeut role cholestyramin',
#  'present case signific anticoagul tempor associ bout protract diarrhea patient warfarin therapi',
#  'present case signific anticoagul tempor associ bout protract diarrhea patient warfarin therapi',
#  'mi relat use activ non activ pcc predominantli affect young patient often preced histori risk factor mi tend associ larg cumul dose concentr',
#  'recombin viia concentr manag bleed follow prothrombin complex concentr relat myocardi infarct patient haemophilia inhibitor',
#  'safe use recombin factor viia treat bleed immedi long term period follow pcc relat mi',
#  'even strict warn took anoth quinin tablet even trigger fifth episod sever thrombocytopenia confirm etiolog quinin induc thrombocytopenia',
#  'even strict warn took anoth quinin tablet even trigger fifth episod sever thrombocytopenia confirm etiolog quinin induc thrombocytopenia',
#  'even strict warn took anoth quinin tablet even trigger fifth episod sever thrombocytopenia confirm etiolog quinin induc thrombocytopenia',
#  'occult quinin induc thrombocytopenia',
#  'three subsequ episod sever symptomat thrombocytopenia next four week say upon repeat question continu take quinin night leg cramp',
#  'year old child famili mediterranean fever exhibit sign colchicin intox receiv prophylact dose drug',
#  'conclus best knowledg first time colchicin intox age group describ english literatur',
#  'near fatal acut colchicin intox child',
#  'near fatal acut colchicin intox child',
# ...
#  'conclus itraconazol induc liver injuri present cholestat pattern injuri damag interlobular bile duct possibl lead ductopenia',
#  'conclus itraconazol induc liver injuri present cholestat pattern injuri damag interlobular bile duct possibl lead ductopenia',
#  'conclus itraconazol induc liver injuri present cholestat pattern injuri damag interlobular bile duct possibl lead ductopenia',
#  'hepatotox relat itraconazol report three case',
#  'method three patient appar itraconazol induc liver injuri studi',
#  'occurr acut hepat best known ketoconazol',
#  'report three patient develop acut liver damag therapi itraconazol liver biopsi specimen obtain',
#  'suggest itraconazol ad list drug may respons drug induc vanish bile duct syndrom',
#  'itraconazol hepatotox reaction rare report histolog data lack',
#  'thrombot stroke associ use porcin factor viii patient acquir haemophilia',
#  'recent encount patient acquir haemophilia develop thrombot left middl cerebr arteri distribut stroke treat pfviii',
#  'specul platelet activ induc pfviii may contribut thrombosi suggest pfviii use caution elderli patient pre exist cardiovascular risk factor',
#  'cutan sarcoidosi interferon alfa ribavirin treatment hepat c viru infect two case',
#  'cutan sarcoidosi interferon alfa ribavirin treatment hepat c viru infect two case',
#  'observ appear aggrav granulomatosi interferon alfa recent combin interferon alfa plu ribavirin',
#  'observ appear aggrav granulomatosi interferon alfa recent combin interferon alfa plu ribavirin',
#  'observ appear aggrav granulomatosi interferon alfa recent combin interferon alfa plu ribavirin',
#  'report two new case sarcoidosi two patient hepat c viru infect treat interferon alfa ribavirin',
#  'report two new case sarcoidosi two patient hepat c viru infect treat interferon alfa ribavirin',
#  'conclus although mirtazapin offer clinician combin strong efficaci good safeti suggest bear ss mind prescrib drug especi frail elderli patient underli chronic condit',
#  'discuss review case ss implic mirtazapin caus perform',
#  'object document case serotonin syndrom ss associ mirtazapin monotherapi review previous report case ss associ tetracycl antidepress discuss possibl pathogen mechan lead seriou advers drug reaction',
#  'object document case serotonin syndrom ss associ mirtazapin monotherapi review previous report case ss associ tetracycl antidepress discuss possibl pathogen mechan lead seriou advers drug reaction',
#  'sever serotonin syndrom induc mirtazapin monotherapi',
#  'pulmonari toxic secondari procarbazin',
#  'year old man present proteinuria postop interferon ifn beta therapi malign melanoma',
#  'minim chang nephrot syndrom develop postop interferon beta therapi malign melanoma',
#  'knowledg first report demonstr histolog abnorm glomerulu associ postop ifn beta therapi malign melanoma',
#  'author report two case delay elimin methotrex patient receiv ciprofloxacin sever toxic',
#  'author report two case delay elimin methotrex patient receiv ciprofloxacin sever toxic',
#  'author report two case delay elimin methotrex patient receiv ciprofloxacin sever toxic',
#  'conclus clinician awar possibl associ thrombocytopenia lansoprazol discontinu drug thrombocytopenia becom appar',
#  'discuss exclus caus onset thrombocytopenia administr lansoprazol resolut advers reaction discontinu drug fact medicin introduc time frame lead us believ like idiosyncrat thrombocytopen respons lansoprazol',
#  'discuss exclus caus onset thrombocytopenia administr lansoprazol resolut advers reaction discontinu drug fact medicin introduc time frame lead us believ like idiosyncrat thrombocytopen respons lansoprazol',
#  'start oral lansoprazol mg twice daili hospit day platelet count decreas x mm hospit day platelet count x mm',
#  'lansoprazol induc thrombocytopenia',
#  'object describ case thrombocytopenia associ administr lansoprazol',
#  'date first report case appear isol thrombocytopenia associ lansoprazol',
#  'life threaten anaphylactoid reaction amifostin use concurr chemoradiotherapi nasopharyng cancer patient dermatomyos case report literatur review',
#  'common side effect associ amifostin nausea vomit hypotens hypocalcemia allerg reaction',
#  'common side effect associ amifostin nausea vomit hypotens hypocalcemia allerg reaction',
#  'common side effect associ amifostin nausea vomit hypotens hypocalcemia allerg reaction',
#  'common side effect associ amifostin nausea vomit hypotens hypocalcemia allerg reaction',
#  'common side effect associ amifostin nausea vomit hypotens hypocalcemia allerg reaction',
#  'patient suffer life threaten anaphylactoid reaction amifostin',
#  'agranulocytosi clozapin therapi',
#  'granulocytopenia agranulocytosi consid among danger advers effect clozapin',
#  'granulocytopenia agranulocytosi consid among danger advers effect clozapin',
#  'femal patient receiv clozapin daili dose mg induc agranulocytosi month',
#  'male patient treat mg day clozapin time diagnosi agranulocytosi week',
#  'year old man develop nm without rigid take olanzapin',
#  'atyp neurolept malign syndrom associ olanzapin',
#  'case summari report case year old patient hospit due behavior alter treat oral zuclopenthixol antipsychot thioxanthen famili develop acut pain erect',
#  'conclus priapism uncommon potenti seriou advers effect zuclopenthixol practition mani antipsychot awar',
#  'discuss occurr priapism patient relat zuclopenthixol',
#  'object present singl case zuclopenthixol induc priapism literatur review',
#  'priapism associ zuclopenthixol',
#  'capac zuclopenthixol induc priapism thought due antagonist activ alpha adrenerg receptor',
#  'identif index patient addit inquiri reveal patient mother hospit previous overwhelm sepsi associ metamizol use',
#  'metamizol nonsteroid antiinflammatori agent prohibit unit state risk agranulocytosi wide use mexico countri',
#  'erythropoietin benefici mitomycin induc hemolyt urem syndrom',
#  'describ patient develop hu treatment mitomycin c total dose mg due carcinoma ascend colon',
#  'levofloxacin induc toxic epiderm necrolysi elderli patient',
#  'knowledg case first publish report levofloxacin induc ten',
#  'year old femal develop multipl episod grand mal seizur combin chemotherapi cisplatin vinblastin bleomycin germ cell ovarian cancer stage ic',
#  'year old femal develop multipl episod grand mal seizur combin chemotherapi cisplatin vinblastin bleomycin germ cell ovarian cancer stage ic',
#  'year old femal develop multipl episod grand mal seizur combin chemotherapi cisplatin vinblastin bleomycin germ cell ovarian cancer stage ic',
#  'posterior leukoencephalopathi follow cisplatin bleomycin vinblastin therapi germ cell tumor ovari',
#  'posterior leukoencephalopathi follow cisplatin bleomycin vinblastin therapi germ cell tumor ovari',
#  'posterior leukoencephalopathi follow cisplatin bleomycin vinblastin therapi germ cell tumor ovari',
#  'day treatment il patient develop hemorrhag lesion progress toxic epiderm necrolysi well grade pancytopenia',
#  'day treatment il patient develop hemorrhag lesion progress toxic epiderm necrolysi well grade pancytopenia',
#  'day treatment il patient develop hemorrhag lesion progress toxic epiderm necrolysi well grade pancytopenia',
#  'object report case cutan hematolog toxic patient treat il',
#  'subcutan il safe well toler mortal rate',
#  'toxic epiderm necrolysi associ interleukin',
#  'case anaphylactoid reaction due sole use gelofusin patient non haemorrhag hypovolaemia present discuss manag use allergi identif jewelleri',
#  'gelofusin allergi need identif jewelleri',
#  'author describ valproat induc hyperammonemia mental statu chang year old man first known report case elderli patient',
#  'author describ valproat induc hyperammonemia mental statu chang year old man first known report case elderli patient',
#  'valproat induc hyperammonemia caus alter mental statu',
#  'valproat induc hyperammonemia caus alter mental statu',
#  'leiomyosarcoma urinari bladder cyclophosphamid therapi retinoblastoma review bladder sarcoma',
#  'epivod nm occur treatment clozapin risperidon amisulprid',
#  'epivod nm occur treatment clozapin risperidon amisulprid',
#  'epivod nm occur treatment clozapin risperidon amisulprid',
#  'year old woman present fever cough week complet third cycl fludarabin chronic lymphocyt leukemia cll',
#  'year old woman present fever cough week complet third cycl fludarabin chronic lymphocyt leukemia cll',
#  'fludarabin induc lung toxic must consid patient develop unexplain lung diseas receiv fludarabin',
#  'fludarabin induc lung toxic must consid patient develop unexplain lung diseas receiv fludarabin',
#  'fludarabin induc lung toxic must consid patient develop unexplain lung diseas receiv fludarabin',
#  'multipl pulmonari nodul unusu present fludarabin pulmonari toxic case report review literatur',
#  'multipl pulmonari nodul unusu present fludarabin pulmonari toxic case report review literatur',
#  'case extend spectrum fludarabin pulmonari toxic includ pulmonari nodul',
#  'case extend spectrum fludarabin pulmonari toxic includ pulmonari nodul',
#  'knowledg four case interstiti pneumon associ fludarabin report medic literatur',
#  'epoprostenol may associ rare sever erythroderma',
#  'sever erythroderma complic continu epoprostenol therapi',
#  'report case patient pulmonari hypertens undifferenti connect tissu diseas month treatment epoprostenol present rapidli progress erythema scale nausea vomit fever',
#  'report case patient pulmonari hypertens undifferenti connect tissu diseas month treatment epoprostenol present rapidli progress erythema scale nausea vomit fever',
#  'report case patient pulmonari hypertens undifferenti connect tissu diseas month treatment epoprostenol present rapidli progress erythema scale nausea vomit fever',
#  'report case patient pulmonari hypertens undifferenti connect tissu diseas month treatment epoprostenol present rapidli progress erythema scale nausea vomit fever',
#  'report case patient pulmonari hypertens undifferenti connect tissu diseas month treatment epoprostenol present rapidli progress erythema scale nausea vomit fever',
#  'year old diabet hypertens male patient report ticlopidin induc marrow aplasia partial respons coloni stimul factor corticosteroid experienc complet recoveri cyclosporin',
#  'consensu treatment ticlopidin induc marrow aplasia',
#  'ticlopidin induc marrow aplasia treat cyclosporin',
#  'year old man develop lower leg edema week rosiglitazon increas mg day mg twice day',
#  'year old man develop bilater lower leg edema month switch troglitazon pioglitazon',
#  'year old man develop ankl hand facial swell week start rosiglitazon',
#  'two case polymorph ventricular tachycardia induc administr verapamil paroxysm supraventricular tachycardia',
#  'verapamil wide use termin paroxysm supraventricular tachycardia psvt littl proarrhythm effect',
#  'describ two case psvt chang non sustain polymorph ventricular tachycardia administr verapamil',
#  'epsilon aminocapro acid renal complic case report review literatur',
#  'neonat mydriasi intraven lidocain advers reaction',
#  'present neonat seizur disord acut develop pupillari mydriasi secondari lidocain overdos',
#  'suggest ad side effect list untoward effect lidocain differenti diagnosi fix dilat pupil neonat treat lidocain',
#  'myelodysplasia termin acut myeloid leukemia hairi cell leukemia patient treat deoxycoformycin',
#  'myelodysplasia termin acut myeloid leukemia hairi cell leukemia patient treat deoxycoformycin',
#  'best knowledg two previou case aml link treatment hcl purin analog chlorodeoxyadenosin',
#  'conclus peripher administr low dose vasopressin septic shock discourag risk ischem skin complic',
#  'object describ case sever skin necrosi result peripher intraven administr low dose vasopressin patient catecholamin resist septic shock',
#  'skin necrosi extravas low dose vasopressin administ septic shock',
#  'mitomycin c induc hemolyt urem syndrom case report',
#  'mitomycin c use wide treatment malign associ seriou dose relat advers effect includ occurr hemolyt urem syndrom',
#  'although vascul report cours hairi cell leukaemia rare report consequ cladribin treatment',
#  'system vascul complic hairi cell leukaemia treatment cladribin',
#  'describ year old woman develop seriou system vascul associ thrombocytopenia cours treatment cladribin',
#  'describ year old woman develop seriou system vascul associ thrombocytopenia cours treatment cladribin',
#  'drug induc mammari hyperplasia report rare complic penicillamin neothetazon',
#  'drug induc mammari hyperplasia report rare complic penicillamin neothetazon',
#  'gigantomastia induc bucillamin',
#  'retrospect bucillamin believ caus giant hypertrophi structur similar penicillamin subject abund report mammari hyperplasia',
#  'retrospect bucillamin believ caus giant hypertrophi structur similar penicillamin subject abund report mammari hyperplasia',
#  'author report first case bucillamin induc giant mammari hyperplasia',
#  'author describ three famili occurr fv sibl strongli suggest hereditari suscept valproic acid induc advers outcom',
#  'fetal valproat syndrom fv character distinct facial appear major minor malform development delay',
#  'fetal valproat syndrom fv character distinct facial appear major minor malform development delay',
#  'fetal valproat syndrom fv character distinct facial appear major minor malform development delay',
#  'fetal valproat syndrom fv character distinct facial appear major minor malform development delay',
#  'fetal valproat syndrom fv character distinct facial appear major minor malform development delay',
#  'valproat embryopathi three set sibl proof hereditari suscept',
#  'generalis pustular psoriasi induc cyclosporin withdraw respond tumour necrosi factor alpha inhibitor etanercept',
#  'report year old male patient year histori psoriasi includ mutil psoriat arthriti withdraw cyclosporin induc generalis pustular exacerb aggrav joint condit',
#  'report year old male patient year histori psoriasi includ mutil psoriat arthriti withdraw cyclosporin induc generalis pustular exacerb aggrav joint condit',
#  'first case concern year old man develop sever aplast anemia week treatment mg ticlopidin daili',
#  'second year old man receiv ticlopidin year febril episod found neutropen marrow aplasia',
#  'second year old man receiv ticlopidin year febril episod found neutropen marrow aplasia',
#  'ticlopidin induc aplast anemia tiaa consid uncommon',
#  'ticlopidin induc aplast anemia tiaa consid uncommon',
#  'ticlopidin induc aplast anemia two new case report review meta analysi addit case',
#  'data patient evalu revers direct cytotox effect ticlopidin pluripot bipot hematopoiet progenitor stem cell propos',
#  'fix drug erupt rofecoxib',
#  'rofecoxib use dysmenorrhea caus herpetiform fix drug erupt predominantli involv lip classic clinic histolog find red brown lesion dorsal hand',
#  'rofecoxib use dysmenorrhea caus herpetiform fix drug erupt predominantli involv lip classic clinic histolog find red brown lesion dorsal hand',
#  'patient treat larg dose thyroid hormon sever year develop featur secondari hypothyroid thyroid hormon withdraw',
#  'background gemcitabin mild renal toxic case gemcitabin associ hemolyt urem syndrom hu report',
#  'background gemcitabin mild renal toxic case gemcitabin associ hemolyt urem syndrom hu report',
#  'background gemcitabin mild renal toxic case gemcitabin associ hemolyt urem syndrom hu report',
#  'background gemcitabin mild renal toxic case gemcitabin associ hemolyt urem syndrom hu report',
#  'background gemcitabin mild renal toxic case gemcitabin associ hemolyt urem syndrom hu report',
#  'conclus confirm case gemcitabin associ hu despit widespread use drug',
#  'gemcitabin associ hemolyt urem syndrom',
#  'mean time initi gemcitabin therapi onset hu month dose gemcitabin',
#  'mean time initi gemcitabin therapi onset hu month dose gemcitabin',
#  'method case present year old woman prolong gemcitabin treatment ovarian cancer develop hu recov drug discontinu',
#  'result includ patient total case gemcitabin associ hu identifi',
#  'amiodaron optic neuropathi describ',
#  ...]

# %% [markdown]
# ## Bag of Words model

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 12000)     # The bag of words model will convert to numeric approch.
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, 1].values               # The test dataset

# %% [markdown]
# ### Train/Test dataset

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (18812, 12000) (18812,)
# Test set: (4704, 12000) (4704,)

# %% [markdown]
# ## Modeling (Naive_bayes with Scikit-learn)

# %%
# Fitting Naive Bayes to the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)    # Fitting train and test dataset
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred[0:5]                         # The first predicted values
# Out:
# array([1, 1, 1, 1, 0], dtype=int64)

# %% [markdown]
# ## Confusion_matrix

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1775, 1558],
#        [ 138, 1233]], dtype=int64)

# %% [markdown]
# ## Accuracy

# %%
# Accuracy of the test
accuracy = (1775+1233)/4704             # (TP+TN)/Total Values
accuracy
# Out:
# 0.6394557823129252

# %% [markdown]
# ## Classification_Report

# %%
from sklearn.metrics import classification_report
print (classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.53      0.68      3333
#            1       0.44      0.90      0.59      1371
#
#     accuracy                           0.64      4704
#    macro avg       0.68      0.72      0.63      4704
# weighted avg       0.79      0.64      0.65      4704

# %% [markdown]
# ## The f1_score from sklearn library

# %%
from sklearn.metrics import f1_score
f1_score = f1_score(y_test, y_pred, average='weighted')
print("Avg F1-score: %.4f" % f1_score)
# Out:
# Avg F1-score: 0.6522

# %% [markdown]
# # Thank You
